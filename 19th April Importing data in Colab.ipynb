# %%
import pandas as pd

sheet_id = "1dvC8S71bbt1rXGfXuQux3gGtHXMB4cmKvo0vZC_eVEw"  # Replace with your ID
sheet_name = "Sheet1"  # Replace with your exact sheet name

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

df = pd.read_csv(url)
df.head()
# Out:
#   Party Name                           Full Name  Age  Number of Followers  \
# 0        BJP              Bharatiya Janata Party   45                  198
# 1        CCP             Chinese Communist Party  103                   99
# 2        INC            Indian National Congress  139                   55
# 3        CPI  Communist Party of India (Marxist)   60                   50
# 4        DEM                    Democratic Party  197                   45
#
#   Country
# 0   India
# 1   China
# 2   India
# 3   India
# 4      US

# %% [markdown]
# Find out the oldest party in the world. (30 points).

# %%
df.sort_values(by='Age', ascending=False).head(1)
# Out:
#   Party Name         Full Name  Age  Number of Followers Country
# 4        DEM  Democratic Party  197                   45      US

# %%
oldest_party = df.loc[df["Age"].idxmax()]
oldest_party
print(oldest_party["Full Name"])
# Out:
# Democratic Party

# %% [markdown]
# 2.Display all the party short names in a list. (50 points)

# %%
# prompt: Display all the party short names in a list.

print(df["Short Name"].to_list())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Short Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-72a62e6a8766> in <cell line: 0>()
#       1 # prompt: Display all the party short names in a list.
#       2
# ...

# %%
party_name = df["Party Name"]
party_name
# Out:
# 0       BJP
# 1       CCP
# 2       INC
# 3       CPI
# 4       DEM
# 5       REP
# 6    AIADMK
# 7       PTI
# 8       DMK
# 9       CCM
# Name: Party Name, dtype: object

# %%
party_name = df["Party Name"]
party_name

party_short_name = []

for i in party_name:
       party_short_name.append(i)

party_short_name
# Out:
# ['BJP', 'CCP', 'INC', 'CPI', 'DEM', 'REP', 'AIADMK', 'PTI', 'DMK', 'CCM']

# %% [markdown]
# What is total numbers of followers of all party.

# %%
df.head()
# Out:
#   Party Name                           Full Name  Age  Number of Followers  \
# 0        BJP              Bharatiya Janata Party   45                  198
# 1        CCP             Chinese Communist Party  103                   99
# 2        INC            Indian National Congress  139                   55
# 3        CPI  Communist Party of India (Marxist)   60                   50
# 4        DEM                    Democratic Party  197                   45
#
#   Country
# 0   India
# 1   China
# 2   India
# 3   India
# 4      US

# %%
print("Number of follower for all parties",df["Number of Followers"].sum())
# Out:
# Number of follower for all parties 555

# %%
# prompt: List out the party which name starts with i

import pandas as pd

sheet_id = "1dvC8S71bbt1rXGfXuQux3gGtHXMB4cmKvo0vZC_eVEw"  # Replace with your ID
sheet_name = "Sheet1"  # Replace with your exact sheet name

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

df = pd.read_csv(url)

# Filter parties whose names start with "i" (case-insensitive)
parties_starting_with_i = df[df['Party Name'].str.lower().str.startswith('i')]

# Print the filtered party names
print(parties_starting_with_i["Party Name"])
# Out:
# 2    INC
# Name: Party Name, dtype: object

# %%
df[df["Full Name"].str.startswith("I")]
# Out:
#   Party Name                 Full Name  Age  Number of Followers Country
# 2        INC  Indian National Congress  139                   55   India

# %%
# party= df[df["Full Name"]
party_name_start_with_I= []

for i in df["Full Name"]:
    i = True
    party_name_start_with_I.append(i)

party_name_start_with_I
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %%
PartyNameStartWithI= []
for i in df["Full Name"]:
    if i.startswith("I"):
      PartyNameStartWithI.append(i)

PartyNameStartWithI
# Out:
# ['Indian National Congress']

# %%
df.iloc[df['Age'].max().index()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7f6e866f63e2> in <cell line: 0>()
# ----> 1 df.iloc[df['Age'].max().index()]
#
# AttributeError: 'int' object has no attribute 'index'

# %% [markdown]
# Display the largest party in the world? (50 points)

# %%
df.nlargest(1, 'Number of Followers')
# Out:
#   Party Name               Full Name  Age  Number of Followers Country
# 0        BJP  Bharatiya Janata Party   45                  198   India

# %%
largest_party = df.loc[df["Number of Followers"].idxmax()]
largest_party
print(largest_party["Party Name"])
# Out:
# BJP

# %% [markdown]
# I need total numbers of followers  across all indian party

# %%
Indian_parties = df[df["Country"] == "India"]
print("Total Follower of Indian Parties" , Indian_parties["Number of Followers"].sum())
df
# Out:
# Total Follower of Indian Parties 343
#   Party Name                                 Full Name  Age  \
# 0        BJP                    Bharatiya Janata Party   45
# 1        CCP                   Chinese Communist Party  103
# 2        INC                  Indian National Congress  139
# 3        CPI        Communist Party of India (Marxist)   60
# 4        DEM                          Democratic Party  197
# 5        REP                          Republican Party  171
# 6     AIADMK  All India Anna Dravida Munnetra Kazhagam   52
# 7        PTI                  Pakistan Tehreek-e-Insaf   28
# 8        DMK                 Dravida Munnetra Kazhagam   75
# 9        CCM                       Chama Cha Mapinduzi   48
#
#    Number of Followers   Country
# 0                  198     India
# 1                   99     China
# 2                   55     India
# 3                   50     India
# 4                   45        US
# 5                   36        US
# ...

# %% [markdown]
# 1AbCDEFg1234567xyz1234567ABCdEfgh

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1dvC8S71bbt1rXGfXuQux3gGtHXMB4cmKvo0vZC_eVEw/edit?usp=drive_link

# %% [markdown]
# Rank all the party based on their age, youngest to oldest,1,2,3,4

# %%
# prompt: Rank all the party based on their age, youngest to oldest,1,2,3,4

df_ranked = df.sort_values(by='Age', ascending=True)
df_ranked['Rank'] = range(1, len(df) + 1)
print(df_ranked[['Party Name', 'Age', 'Rank']])
# Out:
#   Party Name  Age  Rank
# 7        PTI   28     1
# 0        BJP   45     2
# 9        CCM   48     3
# 6     AIADMK   52     4
# 3        CPI   60     5
# 8        DMK   75     6
# 1        CCP  103     7
# 2        INC  139     8
# 5        REP  171     9
# 4        DEM  197    10

# %%
PartybyAge = df.sort_values(by= "Age",ascending=False)
PartybyAge["Rank by Age"] = range(1,len(df)+1)
PartybyAge
# Out:
#   Party Name                                 Full Name  Age  \
# 4        DEM                          Democratic Party  197
# 5        REP                          Republican Party  171
# 2        INC                  Indian National Congress  139
# 1        CCP                   Chinese Communist Party  103
# 8        DMK                 Dravida Munnetra Kazhagam   75
# 3        CPI        Communist Party of India (Marxist)   60
# 6     AIADMK  All India Anna Dravida Munnetra Kazhagam   52
# 9        CCM                       Chama Cha Mapinduzi   48
# 0        BJP                    Bharatiya Janata Party   45
# 7        PTI                  Pakistan Tehreek-e-Insaf   28
#
#    Number of Followers   Country  Rank by Age
# 4                   45        US            1
# 5                   36        US            2
# 2                   55     India            3
# 1                   99     China            4
# 8                   20     India            5
# ...

# %%
rank = range(1,10)
rank= []
# Out:
# range(1, 10)
